# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(
'btc-eth-prices-original.csv',
index_col=0,
parse_dates=True
)

# %%
df.head()
# Out:
#                 Bitcoin  Ether
# Timestamp
# 2017-04-02  1099.169125  48.55
# 2017-04-03  1141.813000  44.13
# 2017-04-04  1141.600363  44.43
# 2017-04-05  1133.079314  44.90
# 2017-04-06  1196.307937  43.23

# %%
df = pd.read_csv(
'btc-eth-prices-original.csv',
parse_dates=True
)

# %%
df.head()
# Out:
#     Timestamp      Bitcoin  Ether
# 0  2017-04-02  1099.169125  48.55
# 1  2017-04-03  1141.813000  44.13
# 2  2017-04-04  1141.600363  44.43
# 3  2017-04-05  1133.079314  44.90
# 4  2017-04-06  1196.307937  43.23

# %%
df = pd.read_csv(
'btc-eth-prices-original.csv',
index_col=1,
parse_dates=True
)
# Out:
# /var/folders/b1/kb8sgylj3rbc1j57qnzh5h1w0000gn/T/ipykernel_21779/4204492506.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(

# %%
df.head()
# Out:
#               Timestamp  Ether
# Bitcoin
# 1099.169125  2017-04-02  48.55
# 1141.813000  2017-04-03  44.13
# 1141.600363  2017-04-04  44.43
# 1133.079314  2017-04-05  44.90
# 1196.307937  2017-04-06  43.23

# %%
df = pd.read_csv(
'btc-eth-prices-original.csv',
index_col=0,
parse_dates=True
)

# %%
df.head()
# Out:
#                 Bitcoin  Ether
# Timestamp
# 2017-04-02  1099.169125  48.55
# 2017-04-03  1141.813000  44.13
# 2017-04-04  1141.600363  44.43
# 2017-04-05  1133.079314  44.90
# 2017-04-06  1196.307937  43.23

# %%
df.plot(figsize=(16, 9))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df.loc['2017-12': '2017-12-15'].plot(y='Ether', figsize = (16,9))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df_na = df.loc['2017-12': '2017-12-15']

# %%
df_na['Ether']. isna().values.any()
# Out:
# True

# %%
df_na.loc[df_na['Ether'].isna()]
# Out:
#                  Bitcoin  Ether
# Timestamp
# 2017-12-08  16007.436667    NaN
# 2017-12-09  15142.834152    NaN
# 2017-12-10  14869.805000    NaN

# %%
df.loc['2017-12-06':'2017-12-12']
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667     NaN
# 2017-12-09  15142.834152     NaN
# 2017-12-10  14869.805000     NaN
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df.loc['2017-12-06':'2017-12-12'].fillna(method='bfill')
# Out:
#                  Bitcoin   Ether
# Timestamp
# 2017-12-06  13540.980000  422.48
# 2017-12-07  16501.971667  421.15
# 2017-12-08  16007.436667  513.29
# 2017-12-09  15142.834152  513.29
# 2017-12-10  14869.805000  513.29
# 2017-12-11  16762.116667  513.29
# 2017-12-12  17276.393333  656.52

# %%
df.fillna(method='bfill',inplace=True)

# %%
df.plot(figsize=(16,9))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['2017-12-25':'2018-01-01'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['2018-03-01':'2018-03-09'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df_cleaned = df.drop(pd.to_datetime(['2017-12-28', '2018-03-04']))

# %%
df_cleaned.plot(figsize=(16,9))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
#cleaning analysis

# %%
df.mean()
# Out:
# Bitcoin    6359.574241
# Ether       430.612685
# dtype: float64

# %%
#outliers are skewing

# %%
df_cleaned.mean()
# Out:
# Bitcoin    6323.509186
# Ether       428.628402
# dtype: float64

# %%
df.median()
# Out:
# Bitcoin    4594.98785
# Ether       309.49000
# dtype: float64

# %%
df.mode()
# Out:
#           Bitcoin   Ether
# 0     1099.169125  513.29
# 1     1133.079314     NaN
# 2     1141.600363     NaN
# 3     1141.813000     NaN
# 4     1180.023713     NaN
# ..            ...     ...
# 360  17737.111667     NaN
# 361  17771.900000     NaN
# 362  18961.856667     NaN
# 363  19289.785000     NaN
# 364  19498.683333     NaN
#
# [365 rows x 2 columns]

# %%
#visualizing distribution

# %%
df_cleaned.plot(kind='hist', y='Ether', bins = 150)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_cleaned.plot(kind='hist', y='Bitcoin', bins = 150)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#using seaborn

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.displot(df_cleaned['Ether'], ax=ax)
# Out:
# /Users/bishal/anaconda3/lib/python3.11/site-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Users/bishal/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.distplot(df_cleaned['Bitcoin'], rug=True, ax=ax)
# Out:
# /var/folders/b1/kb8sgylj3rbc1j57qnzh5h1w0000gn/T/ipykernel_21779/3559312923.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_cleaned['Bitcoin'], rug=True, ax=ax)
# <Axes: xlabel='Bitcoin', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.kdeplot(df_cleaned['Ether'], shade=True, cut=0, ax=ax)
sns.rugplot(df_cleaned['Ether'], ax=ax);
# Out:
# /var/folders/b1/kb8sgylj3rbc1j57qnzh5h1w0000gn/T/ipykernel_21779/3001299526.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_cleaned['Ether'], shade=True, cut=0, ax=ax)

# %%
#visualizing bivariate distributions

# %%
sns.jointplot(x="Bitcoin", y="Ether", data=df_cleaned, size=9)

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.regplot(x="Bitcoin", y="Ether", data=df_cleaned, ax=ax)
# Out:
# <Axes: xlabel='Bitcoin', ylabel='Ether'>

# %%
#quantiles.quartiles and percentiles

# %%
df_cleaned['Bitcoin'].quantile(.2)
# Out:
# 2438.8627342857144

# %%
#dispersion

# %%
df['Bitcoin'].max() - df['Bitcoin'].min()
# Out:
# 18399.514208333334

# %%
df_cleaned['Bitcoin'].max()-df_cleaned['Bitcoin'].min()
# Out:
# 18399.514208333334

# %%
df['Bitcoin'].var()
# Out:
# 20510743.821548793

# %%
df['Bitcoin'].std()
# Out:
# 4528.878870266768

# %%
df_cleaned['Bitcoin'].std()
# Out:
# 4513.757662530281

# %%
#interquarter range

# %%
df['Bitcoin'].quantile(.75)-df['Bitcoin'].quantile(.25)
# Out:
# 6597.494147619047

# %%
df_cleaned['Bitcoin'].quantile(.75)-df_cleaned['Bitcoin'].quantile(.25)
# Out:
# 6548.249242559523

# %%
#cleaning invalid data analytically

# %%
upper_limit = df['Bitcoin'].mean() + 2*df['Bitcoin'].std()

# %%
df[df['Bitcoin'] < upper_limit].plot(figsize=(16, 7))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df.drop(df[df['Bitcoin'] > upper_limit].index).plot(figsize=(16, 7))
# Out:
# <Axes: xlabel='Timestamp'>

# %%
filepath = 'btc-eth-prices-original.csv'
with open (filepath, 'r') as reader:
    print (reader)
# Out:
# <_io.TextIOWrapper name='btc-eth-prices-original.csv' mode='r' encoding='UTF-8'>

# %%
filepath = 'btc-eth-prices-original.csv'
with open (filepath, 'r') as reader:
    for index, line in enumerate (reader.readlines()):
        if(index<10):
            print(index, line)
# Out:
# 0 Timestamp,Bitcoin,Ether
#
# 1 2017-04-02,1099.169125,48.55
#
# 2 2017-04-03,1141.813,44.13
#
# 3 2017-04-04,1141.6003625,44.43
#
# 4 2017-04-05,1133.0793142857142,44.9
#
# 5 2017-04-06,1196.3079375,43.23
#
# 6 2017-04-07,1190.45425,42.31
#
# 7 2017-04-08,1181.1498375,44.37
#
# 8 2017-04-09,1208.8005,43.72
#
# 9 2017-04-10,1207.744875,43.74

# %%
#read_csv method

# %%
csv_url = 'https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv'
pd.read_csv(csv_url).head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df = pd.read_csv('btc-eth-prices-original.csv')
df.head()
# Out:
#     Timestamp      Bitcoin  Ether
# 0  2017-04-02  1099.169125  48.55
# 1  2017-04-03  1141.813000  44.13
# 2  2017-04-04  1141.600363  44.43
# 3  2017-04-05  1133.079314  44.90
# 4  2017-04-06  1196.307937  43.23

# %%
#first row behavior with header parameters

# %%
df = pd.read_csv('btc-market-price.csv',
                header = None)

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
#missing values with na_values parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                header = None,
                na_values = ['','?','-'])

# %%
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
#column names using names parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                header = None,
                na_values = ['','?', '-'],
                names = ['Timestamp', 'Price'])

# %%
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
#column types using dtype parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                header = None,
                na_values = ['','?', '-'],
                names = ['Timestamp', 'Price'],
                dtype = {'Price': 'float'})

# %%
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
#adding index to our data using index_col parameter

# %%
df = pd.read_csv('btc-market-price.csv',
                 header = None,
                 na_values = ['','?', '-'],
                 names = ['Timestamp', 'Price'],
                 dtype = {'Price': 'float'},
                 parse_dates = [0],
                 index_col=[0])

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-02  1099.169125
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937

# %%
df.dtypes
# Out:
# Price    float64
# dtype: object

# %%
# a more challening parsing

# %%
first_name>last_name>age>math_score>french_score
Ray>Morley>18>"68,000">"75,000"
Melvin>Scott>24>77>83
Amirah>Haley>22>92>67

Gerard>Mills>19>"78,000">72
Amy>Grimes>23>91>81
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 first_name>last_name>age>math_score>french_score
#       2 Ray>Morley>18>"68,000">"75,000"
#       3 Melvin>Scott>24>77>83
#
# NameError: name 'first_name' is not defined

# %%
# a more challenging parsing

# %%
exam_df = pd.read_csv('exam_review.csv')

# %%
exam_df
# Out:
#                                first_name>last_name>age>math_score>french_score
# Ray>Morley>18>"68     000">"75                                             000"
# Melvin>Scott>24>77>83 NaN                                                   NaN
# Amirah>Haley>22>92>67 NaN                                                   NaN
# Gerard>Mills>19>"78   000">72                                               NaN
# Amy>Grimes>23>91>81   NaN                                                   NaN

# %%
#custom data delimiters using sep parameter

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
#custom numeric decimal and thousands character

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      object
# french_score    object
# dtype: object

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep = '>',
                     decimal = ',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      float64
# french_score    float64
# dtype: object

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep = '>',
                     thousands = ',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18       68000         75000
# 1     Melvin     Scott   24          77            83
# 2     Amirah     Haley   22          92            67
# 3     Gerard     Mills   19       78000            72
# 4        Amy    Grimes   23          91            81

# %%
#excluding specific rows

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep = '>',
                     decimal = ',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep = '>',
                     skiprows = 2)

# %%
exam_df
# Out:
#    Melvin   Scott  24      77  83
# 0  Amirah   Haley  22      92  67
# 1  Gerard   Mills  19  78,000  72
# 2     Amy  Grimes  23      91  81

# %%
exam_df = pd.read_csv('exam_review.csv',
                     sep = '>',
                     skiprows = [1,3])

# %%
exam_df
# Out:
#   first_name last_name  age math_score  french_score
# 0     Melvin     Scott   24         77            83
# 1     Gerard     Mills   19     78,000            72
# 2        Amy    Grimes   23         91            81

# %%
#get rid of blank lines

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            skip_blank_lines=False)
# Out:
#   first_name last_name   age math_score french_score
# 0        Ray    Morley  18.0     68,000       75,000
# 1     Melvin     Scott  24.0         77           83
# 2     Amirah     Haley  22.0         92           67
# 3        NaN       NaN   NaN        NaN          NaN
# 4     Gerard     Mills  19.0     78,000           72
# 5        Amy    Grimes  23.0         91           81

# %%
#loading specific columns

# %%
pd.read_csv('exam_review.csv',
           usecols = ['first_name', 'last_name', 'age'],
           sep = '>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
pd.read_csv('exam_review.csv',
            usecols=[0, 1, 2],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
#using a series instead of dataframe

# %%
exam_test_1 = pd.read_csv('exam_review.csv',
                         sep = '>',
                         usecols = ['last_name'])

# %%
type(exam_test_1)
# Out:
# pandas.core.frame.DataFrame

# %%
exam_test_2 = pd.read_csv('exam_review.csv',
                          sep='>',
                          usecols=['last_name'],
                          squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 exam_test_2 = pd.read_csv('exam_review.csv',
#       2                           sep='>',
#       3                           usecols=['last_name'],
#       4                           squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
exam_df
# Out:
#   first_name last_name  age math_score  french_score
# 0     Melvin     Scott   24         77            83
# 1     Gerard     Mills   19     78,000            72
# 2        Amy    Grimes   23         91            81

# %%
exam_df.to_csv()
# Out:
# ',first_name,last_name,age,math_score,french_score\n0,Melvin,Scott,24,77,83\n1,Gerard,Mills,19,"78,000",72\n2,Amy,Grimes,23,91,81\n'

# %%
exam_df.to_csv('out.csv')

# %%
pd.read_csv('out.csv')
# Out:
#    Unnamed: 0 first_name last_name  age math_score  french_score
# 0           0     Melvin     Scott   24         77            83
# 1           1     Gerard     Mills   19     78,000            72
# 2           2        Amy    Grimes   23         91            81

# %%
exam_df.to_csv('out.csv',
              index=None)

# %%
pd.read_csv('out.csv')
# Out:
#   first_name last_name  age math_score  french_score
# 0     Melvin     Scott   24         77            83
# 1     Gerard     Mills   19     78,000            72
# 2        Amy    Grimes   23         91            81

# %%
#thank you

# %%
#parse HTML and saving data

# %%
#parsing HTMl tables from the web

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 1

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2  1.4
# 1  2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3  2.2
# 2  3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3  1.4
# 3  4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9  4.6
# 4  5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0  5.3
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %%
#complex example

# %%
import requests

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"

# %%
r = requests.get(html_url)
wiki_tables = pd.read_html(r.text, header=0)

# %%
len(wiki_tables)
# Out:
# 47

# %%
simpsons = wiki_tables[1]

# %%
simpsons.head()
# Out:
#                                         Cast members  \
# 0                                                NaN
# 1                                   Dan Castellaneta
# 2  Homer Simpson, Abe Simpson, Krusty the Clown, ...
#
#                                       Cast members.1  \
# 0                                                NaN
# 1                                       Julie Kavner
# 2  Marge Simpson, Patty and Selma Bouvier, additi...
#
#                                      Cast members.2  Cast members.3  \
# 0                                               NaN             NaN
# 1                                  Nancy Cartwright  Yeardley Smith
# 2  Bart Simpson, Maggie Simpson, various characters    Lisa Simpson
#
#                                       Cast members.4  \
# 0                                                NaN
# 1                                        Hank Azaria
# 2  Moe Szyslak, Chief Wiggum, Apu Nahasapeemapeti...
#
# ...

# %%
simpsons.drop([0,1], inplace = True)

# %%
simpsons.set_index('Cast members', inplace = True)

# %%
#different table

# %%
simpsons.head()
# Out:
#                                                                                        Cast members.1  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Marge Simpson, Patty and Selma Bouvier, additi...
#
#                                                                                       Cast members.2  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Bart Simpson, Maggie Simpson, various characters
#
#                                                    Cast members.3  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...   Lisa Simpson
#
#                                                                                        Cast members.4  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Moe Szyslak, Chief Wiggum, Apu Nahasapeemapeti...
#
#                                                                                        Cast members.5  \
# Cast members
# ...

# %%
simpsons.to_csv('out.csv')

# %%
pd.read_csv('out.csv', index_col='Cast members').head()
# Out:
#                                                                                        Cast members.1  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Marge Simpson, Patty and Selma Bouvier, additi...
#
#                                                                                       Cast members.2  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Bart Simpson, Maggie Simpson, various characters
#
#                                                    Cast members.3  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...   Lisa Simpson
#
#                                                                                        Cast members.4  \
# Cast members
# Homer Simpson, Abe Simpson, Krusty the Clown, v...  Moe Szyslak, Chief Wiggum, Apu Nahasapeemapeti...
#
#                                                                                        Cast members.5  \
# Cast members
# ...

# %%
#thank you

# %%
#python in under 10 minutes
